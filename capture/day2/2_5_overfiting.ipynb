# %% [markdown]
# # 準備

# %% [markdown]
# ## Googleドライブのマウント

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## sys.pathの設定

# %% [markdown]
# 以下では，Googleドライブのマイドライブ直下にDNN_codeフォルダを置くことを仮定しています．必要に応じて，パスを変更してください．

# %%
import sys
sys.path.append('/content/drive/My Drive/DNN_code')
sys.path.append('/content/drive/My Drive/DNN_code/lesson_2')

# %% [markdown]
# # overfiting

# %%
import numpy as np
from collections import OrderedDict
from common import layers
from data.mnist import load_mnist
import matplotlib.pyplot as plt
from multi_layer_net import MultiLayerNet
from common import optimizer


(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True)

print("データ読み込み完了")

# 過学習を再現するために、学習データを削減
x_train = x_train[:300]
d_train = d_train[:300]

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10)
optimizer = optimizer.SGD(learning_rate=0.01)

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10


for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    grad = network.gradient(x_batch, d_batch)
    optimizer.update(network.params, grad)

    loss = network.loss(x_batch, d_batch)
    train_loss_list.append(loss)
        
    if (i+1) % plot_interval == 0:
        accr_train = network.accuracy(x_train, d_train)
        accr_test = network.accuracy(x_test, d_test)
        accuracies_train.append(accr_train)
        accuracies_test.append(accr_test)

        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))        

lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.20666666666666667
#                 : 10. 正答率(テスト) = 0.1541
# Generation: 20. 正答率(トレーニング) = 0.3433333333333333
#                 : 20. 正答率(テスト) = 0.2273
# Generation: 30. 正答率(トレーニング) = 0.44333333333333336
#                 : 30. 正答率(テスト) = 0.2848
# Generation: 40. 正答率(トレーニング) = 0.5033333333333333
#                 : 40. 正答率(テスト) = 0.3323
# Generation: 50. 正答率(トレーニング) = 0.5766666666666667
#                 : 50. 正答率(テスト) = 0.3643
# Generation: 60. 正答率(トレーニング) = 0.61
#                 : 60. 正答率(テスト) = 0.4188
# Generation: 70. 正答率(トレーニング) = 0.65
#                 : 70. 正答率(テスト) = 0.4553
# Generation: 80. 正答率(トレーニング) = 0.66
#                 : 80. 正答率(テスト) = 0.4721
# Generation: 90. 正答率(トレーニング) = 0.7
#                 : 90. 正答率(テスト) = 0.5217
# Generation: 100. 正答率(トレーニング) = 0.7366666666666667
#                 : 100. 正答率(テスト) = 0.5649
# Generation: 110. 正答率(トレーニング) = 0.7566666666666667
#                 : 110. 正答率(テスト) = 0.5897
# Generation: 120. 正答率(トレーニング) = 0.8
#                 : 120. 正答率(テスト) = 0.6234
# Generation: 130. 正答率(トレーニング) = 0.8233333333333334
#                 : 130. 正答率(テスト) = 0.6254
# Generation: 140. 正答率(トレーニング) = 0.85
#                 : 140. 正答率(テスト) = 0.6458
# Generation: 150. 正答率(トレーニング) = 0.86
#                 : 150. 正答率(テスト) = 0.6588
# Generation: 160. 正答率(トレーニング) = 0.8833333333333333
#                 : 160. 正答率(テスト) = 0.6718
# Generation: 170. 正答率(トレーニング) = 0.89
#                 : 170. 正答率(テスト) = 0.676
# Generation: 180. 正答率(トレーニング) = 0.9133333333333333
#                 : 180. 正答率(テスト) = 0.6943
# Generation: 190. 正答率(トレーニング) = 0.9233333333333333
#                 : 190. 正答率(テスト) = 0.7048
# Generation: 200. 正答率(トレーニング) = 0.92
#                 : 200. 正答率(テスト) = 0.6959
# Generation: 210. 正答率(トレーニング) = 0.9366666666666666
#                 : 210. 正答率(テスト) = 0.7126
# Generation: 220. 正答率(トレーニング) = 0.94
#                 : 220. 正答率(テスト) = 0.7104
# Generation: 230. 正答率(トレーニング) = 0.9533333333333334
#                 : 230. 正答率(テスト) = 0.7215
# Generation: 240. 正答率(トレーニング) = 0.9566666666666667
#                 : 240. 正答率(テスト) = 0.7193
# Generation: 250. 正答率(トレーニング) = 0.9633333333333334
#                 : 250. 正答率(テスト) = 0.7127
# Generation: 260. 正答率(トレーニング) = 0.9733333333333334
#                 : 260. 正答率(テスト) = 0.7204
# Generation: 270. 正答率(トレーニング) = 0.9833333333333333
#                 : 270. 正答率(テスト) = 0.7283
# Generation: 280. 正答率(トレーニング) = 0.98
#                 : 280. 正答率(テスト) = 0.7314
# Generation: 290. 正答率(トレーニング) = 0.9966666666666667
#                 : 290. 正答率(テスト) = 0.7321
# Generation: 300. 正答率(トレーニング) = 0.9933333333333333
#                 : 300. 正答率(テスト) = 0.731
# Generation: 310. 正答率(トレーニング) = 0.99
#                 : 310. 正答率(テスト) = 0.7377
# Generation: 320. 正答率(トレーニング) = 0.9966666666666667
#                 : 320. 正答率(テスト) = 0.7388
# Generation: 330. 正答率(トレーニング) = 1.0
#                 : 330. 正答率(テスト) = 0.7401
# Generation: 340. 正答率(トレーニング) = 0.9966666666666667
#                 : 340. 正答率(テスト) = 0.7357
# Generation: 350. 正答率(トレーニング) = 1.0
#                 : 350. 正答率(テスト) = 0.7366
# Generation: 360. 正答率(トレーニング) = 0.9966666666666667
#                 : 360. 正答率(テスト) = 0.7383
# Generation: 370. 正答率(トレーニング) = 1.0
#                 : 370. 正答率(テスト) = 0.7396
# Generation: 380. 正答率(トレーニング) = 1.0
#                 : 380. 正答率(テスト) = 0.7441
# Generation: 390. 正答率(トレーニング) = 1.0
#                 : 390. 正答率(テスト) = 0.7433
# Generation: 400. 正答率(トレーニング) = 1.0
#                 : 400. 正答率(テスト) = 0.7435
# Generation: 410. 正答率(トレーニング) = 1.0
#                 : 410. 正答率(テスト) = 0.7451
# Generation: 420. 正答率(トレーニング) = 1.0
#                 : 420. 正答率(テスト) = 0.7453
# Generation: 430. 正答率(トレーニング) = 1.0
#                 : 430. 正答率(テスト) = 0.7476
# Generation: 440. 正答率(トレーニング) = 1.0
#                 : 440. 正答率(テスト) = 0.7469
# Generation: 450. 正答率(トレーニング) = 1.0
#                 : 450. 正答率(テスト) = 0.746
# Generation: 460. 正答率(トレーニング) = 1.0
#                 : 460. 正答率(テスト) = 0.747
# Generation: 470. 正答率(トレーニング) = 1.0
#                 : 470. 正答率(テスト) = 0.748
# Generation: 480. 正答率(トレーニング) = 1.0
#                 : 480. 正答率(テスト) = 0.747
# Generation: 490. 正答率(トレーニング) = 1.0
#                 : 490. 正答率(テスト) = 0.7504
# Generation: 500. 正答率(トレーニング) = 1.0
#                 : 500. 正答率(テスト) = 0.75
# Generation: 510. 正答率(トレーニング) = 1.0
#                 : 510. 正答率(テスト) = 0.7494
# Generation: 520. 正答率(トレーニング) = 1.0
#                 : 520. 正答率(テスト) = 0.7509
# Generation: 530. 正答率(トレーニング) = 1.0
#                 : 530. 正答率(テスト) = 0.7487
# Generation: 540. 正答率(トレーニング) = 1.0
#                 : 540. 正答率(テスト) = 0.7497
# Generation: 550. 正答率(トレーニング) = 1.0
#                 : 550. 正答率(テスト) = 0.7516
# Generation: 560. 正答率(トレーニング) = 1.0
#                 : 560. 正答率(テスト) = 0.7492
# Generation: 570. 正答率(トレーニング) = 1.0
#                 : 570. 正答率(テスト) = 0.7494
# Generation: 580. 正答率(トレーニング) = 1.0
#                 : 580. 正答率(テスト) = 0.7498
# Generation: 590. 正答率(トレーニング) = 1.0
#                 : 590. 正答率(テスト) = 0.7517
# Generation: 600. 正答率(トレーニング) = 1.0
#                 : 600. 正答率(テスト) = 0.7523
# Generation: 610. 正答率(トレーニング) = 1.0
#                 : 610. 正答率(テスト) = 0.7537
# Generation: 620. 正答率(トレーニング) = 1.0
#                 : 620. 正答率(テスト) = 0.7539
# Generation: 630. 正答率(トレーニング) = 1.0
#                 : 630. 正答率(テスト) = 0.7528
# Generation: 640. 正答率(トレーニング) = 1.0
#                 : 640. 正答率(テスト) = 0.7527
# Generation: 650. 正答率(トレーニング) = 1.0
#                 : 650. 正答率(テスト) = 0.7531
# Generation: 660. 正答率(トレーニング) = 1.0
#                 : 660. 正答率(テスト) = 0.755
# Generation: 670. 正答率(トレーニング) = 1.0
#                 : 670. 正答率(テスト) = 0.7561
# Generation: 680. 正答率(トレーニング) = 1.0
#                 : 680. 正答率(テスト) = 0.7538
# Generation: 690. 正答率(トレーニング) = 1.0
#                 : 690. 正答率(テスト) = 0.7531
# Generation: 700. 正答率(トレーニング) = 1.0
#                 : 700. 正答率(テスト) = 0.7546
# Generation: 710. 正答率(トレーニング) = 1.0
#                 : 710. 正答率(テスト) = 0.7547
# Generation: 720. 正答率(トレーニング) = 1.0
#                 : 720. 正答率(テスト) = 0.7542
# Generation: 730. 正答率(トレーニング) = 1.0
#                 : 730. 正答率(テスト) = 0.7547
# Generation: 740. 正答率(トレーニング) = 1.0
#                 : 740. 正答率(テスト) = 0.755
# Generation: 750. 正答率(トレーニング) = 1.0
#                 : 750. 正答率(テスト) = 0.7563
# Generation: 760. 正答率(トレーニング) = 1.0
#                 : 760. 正答率(テスト) = 0.755
# Generation: 770. 正答率(トレーニング) = 1.0
#                 : 770. 正答率(テスト) = 0.7566
# Generation: 780. 正答率(トレーニング) = 1.0
#                 : 780. 正答率(テスト) = 0.755
# Generation: 790. 正答率(トレーニング) = 1.0
#                 : 790. 正答率(テスト) = 0.7543
# Generation: 800. 正答率(トレーニング) = 1.0
#                 : 800. 正答率(テスト) = 0.7558
# Generation: 810. 正答率(トレーニング) = 1.0
#                 : 810. 正答率(テスト) = 0.7551
# Generation: 820. 正答率(トレーニング) = 1.0
#                 : 820. 正答率(テスト) = 0.7547
# Generation: 830. 正答率(トレーニング) = 1.0
#                 : 830. 正答率(テスト) = 0.7567
# Generation: 840. 正答率(トレーニング) = 1.0
#                 : 840. 正答率(テスト) = 0.7568
# Generation: 850. 正答率(トレーニング) = 1.0
#                 : 850. 正答率(テスト) = 0.7564
# Generation: 860. 正答率(トレーニング) = 1.0
#                 : 860. 正答率(テスト) = 0.7561
# Generation: 870. 正答率(トレーニング) = 1.0
#                 : 870. 正答率(テスト) = 0.7568
# Generation: 880. 正答率(トレーニング) = 1.0
#                 : 880. 正答率(テスト) = 0.7566
# Generation: 890. 正答率(トレーニング) = 1.0
#                 : 890. 正答率(テスト) = 0.756
# Generation: 900. 正答率(トレーニング) = 1.0
#                 : 900. 正答率(テスト) = 0.757
# Generation: 910. 正答率(トレーニング) = 1.0
#                 : 910. 正答率(テスト) = 0.7563
# Generation: 920. 正答率(トレーニング) = 1.0
#                 : 920. 正答率(テスト) = 0.757
# Generation: 930. 正答率(トレーニング) = 1.0
#                 : 930. 正答率(テスト) = 0.7565
# Generation: 940. 正答率(トレーニング) = 1.0
#                 : 940. 正答率(テスト) = 0.7564
# Generation: 950. 正答率(トレーニング) = 1.0
#                 : 950. 正答率(テスト) = 0.7571
# Generation: 960. 正答率(トレーニング) = 1.0
#                 : 960. 正答率(テスト) = 0.7577
# Generation: 970. 正答率(トレーニング) = 1.0
#                 : 970. 正答率(テスト) = 0.7573
# Generation: 980. 正答率(トレーニング) = 1.0
#                 : 980. 正答率(テスト) = 0.7578
# Generation: 990. 正答率(トレーニング) = 1.0
#                 : 990. 正答率(テスト) = 0.7584
# Generation: 1000. 正答率(トレーニング) = 1.0
#                 : 1000. 正答率(テスト) = 0.7583

# %% [markdown]
# ## weight decay
# ### L2

# %%
from common import optimizer

(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True)

print("データ読み込み完了")

# 過学習を再現するために、学習データを削減
x_train = x_train[:300]
d_train = d_train[:300]


network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10)


iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100
learning_rate=0.01

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10
hidden_layer_num = network.hidden_layer_num

# 正則化強度設定 ======================================
weight_decay_lambda = 0.1
# =================================================

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    grad = network.gradient(x_batch, d_batch)
    weight_decay = 0
    
    for idx in range(1, hidden_layer_num+1):
        grad['W' + str(idx)] = network.layers['Affine' + str(idx)].dW + weight_decay_lambda * network.params['W' + str(idx)]
        grad['b' + str(idx)] = network.layers['Affine' + str(idx)].db
        network.params['W' + str(idx)] -= learning_rate * grad['W' + str(idx)]
        network.params['b' + str(idx)] -= learning_rate * grad['b' + str(idx)]        
        weight_decay += 0.5 * weight_decay_lambda * np.sqrt(np.sum(network.params['W' + str(idx)] ** 2))

    loss = network.loss(x_batch, d_batch) + weight_decay
    train_loss_list.append(loss)        
        
    if (i+1) % plot_interval == 0:
        accr_train = network.accuracy(x_train, d_train)
        accr_test = network.accuracy(x_test, d_test)
        accuracies_train.append(accr_train)
        accuracies_test.append(accr_test)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))               


lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.19
#                 : 10. 正答率(テスト) = 0.1632
# Generation: 20. 正答率(トレーニング) = 0.28
#                 : 20. 正答率(テスト) = 0.2215
# Generation: 30. 正答率(トレーニング) = 0.3333333333333333
#                 : 30. 正答率(テスト) = 0.2692
# Generation: 40. 正答率(トレーニング) = 0.36
#                 : 40. 正答率(テスト) = 0.2895
# Generation: 50. 正答率(トレーニング) = 0.41333333333333333
#                 : 50. 正答率(テスト) = 0.3182
# Generation: 60. 正答率(トレーニング) = 0.4533333333333333
#                 : 60. 正答率(テスト) = 0.3413
# Generation: 70. 正答率(トレーニング) = 0.49333333333333335
#                 : 70. 正答率(テスト) = 0.3752
# Generation: 80. 正答率(トレーニング) = 0.5333333333333333
#                 : 80. 正答率(テスト) = 0.4123
# Generation: 90. 正答率(トレーニング) = 0.5566666666666666
#                 : 90. 正答率(テスト) = 0.4255
# Generation: 100. 正答率(トレーニング) = 0.5866666666666667
#                 : 100. 正答率(テスト) = 0.451
# Generation: 110. 正答率(トレーニング) = 0.6066666666666667
#                 : 110. 正答率(テスト) = 0.4805
# Generation: 120. 正答率(トレーニング) = 0.64
#                 : 120. 正答率(テスト) = 0.5106
# Generation: 130. 正答率(トレーニング) = 0.6466666666666666
#                 : 130. 正答率(テスト) = 0.5226
# Generation: 140. 正答率(トレーニング) = 0.66
#                 : 140. 正答率(テスト) = 0.5379
# Generation: 150. 正答率(トレーニング) = 0.6833333333333333
#                 : 150. 正答率(テスト) = 0.5554
# Generation: 160. 正答率(トレーニング) = 0.72
#                 : 160. 正答率(テスト) = 0.5849
# Generation: 170. 正答率(トレーニング) = 0.7566666666666667
#                 : 170. 正答率(テスト) = 0.6114
# Generation: 180. 正答率(トレーニング) = 0.7566666666666667
#                 : 180. 正答率(テスト) = 0.6165
# Generation: 190. 正答率(トレーニング) = 0.8033333333333333
#                 : 190. 正答率(テスト) = 0.6444
# Generation: 200. 正答率(トレーニング) = 0.8066666666666666
#                 : 200. 正答率(テスト) = 0.6526
# Generation: 210. 正答率(トレーニング) = 0.8133333333333334
#                 : 210. 正答率(テスト) = 0.6579
# Generation: 220. 正答率(トレーニング) = 0.8233333333333334
#                 : 220. 正答率(テスト) = 0.6673
# Generation: 230. 正答率(トレーニング) = 0.84
#                 : 230. 正答率(テスト) = 0.6757
# Generation: 240. 正答率(トレーニング) = 0.8366666666666667
#                 : 240. 正答率(テスト) = 0.6791
# Generation: 250. 正答率(トレーニング) = 0.8533333333333334
#                 : 250. 正答率(テスト) = 0.6831
# Generation: 260. 正答率(トレーニング) = 0.8433333333333334
#                 : 260. 正答率(テスト) = 0.6896
# Generation: 270. 正答率(トレーニング) = 0.8533333333333334
#                 : 270. 正答率(テスト) = 0.6983
# Generation: 280. 正答率(トレーニング) = 0.8733333333333333
#                 : 280. 正答率(テスト) = 0.7015
# Generation: 290. 正答率(トレーニング) = 0.86
#                 : 290. 正答率(テスト) = 0.7015
# Generation: 300. 正答率(トレーニング) = 0.85
#                 : 300. 正答率(テスト) = 0.7
# Generation: 310. 正答率(トレーニング) = 0.88
#                 : 310. 正答率(テスト) = 0.7058
# Generation: 320. 正答率(トレーニング) = 0.8633333333333333
#                 : 320. 正答率(テスト) = 0.7022
# Generation: 330. 正答率(トレーニング) = 0.8766666666666667
#                 : 330. 正答率(テスト) = 0.7088
# Generation: 340. 正答率(トレーニング) = 0.84
#                 : 340. 正答率(テスト) = 0.7034
# Generation: 350. 正答率(トレーニング) = 0.86
#                 : 350. 正答率(テスト) = 0.708
# Generation: 360. 正答率(トレーニング) = 0.8766666666666667
#                 : 360. 正答率(テスト) = 0.7046
# Generation: 370. 正答率(トレーニング) = 0.8633333333333333
#                 : 370. 正答率(テスト) = 0.7147
# Generation: 380. 正答率(トレーニング) = 0.8866666666666667
#                 : 380. 正答率(テスト) = 0.7183
# Generation: 390. 正答率(トレーニング) = 0.8766666666666667
#                 : 390. 正答率(テスト) = 0.714
# Generation: 400. 正答率(トレーニング) = 0.8833333333333333
#                 : 400. 正答率(テスト) = 0.7225
# Generation: 410. 正答率(トレーニング) = 0.8833333333333333
#                 : 410. 正答率(テスト) = 0.7158
# Generation: 420. 正答率(トレーニング) = 0.8933333333333333
#                 : 420. 正答率(テスト) = 0.7261
# Generation: 430. 正答率(トレーニング) = 0.8966666666666666
#                 : 430. 正答率(テスト) = 0.724
# Generation: 440. 正答率(トレーニング) = 0.8833333333333333
#                 : 440. 正答率(テスト) = 0.7172
# Generation: 450. 正答率(トレーニング) = 0.9066666666666666
#                 : 450. 正答率(テスト) = 0.7216
# Generation: 460. 正答率(トレーニング) = 0.8866666666666667
#                 : 460. 正答率(テスト) = 0.7206
# Generation: 470. 正答率(トレーニング) = 0.8866666666666667
#                 : 470. 正答率(テスト) = 0.7221
# Generation: 480. 正答率(トレーニング) = 0.9033333333333333
#                 : 480. 正答率(テスト) = 0.7205
# Generation: 490. 正答率(トレーニング) = 0.9033333333333333
#                 : 490. 正答率(テスト) = 0.7251
# Generation: 500. 正答率(トレーニング) = 0.8933333333333333
#                 : 500. 正答率(テスト) = 0.722
# Generation: 510. 正答率(トレーニング) = 0.9
#                 : 510. 正答率(テスト) = 0.7233
# Generation: 520. 正答率(トレーニング) = 0.9066666666666666
#                 : 520. 正答率(テスト) = 0.7265
# Generation: 530. 正答率(トレーニング) = 0.9066666666666666
#                 : 530. 正答率(テスト) = 0.7227
# Generation: 540. 正答率(トレーニング) = 0.9
#                 : 540. 正答率(テスト) = 0.7254
# Generation: 550. 正答率(トレーニング) = 0.91
#                 : 550. 正答率(テスト) = 0.7235
# Generation: 560. 正答率(トレーニング) = 0.89
#                 : 560. 正答率(テスト) = 0.7215
# Generation: 570. 正答率(トレーニング) = 0.9266666666666666
#                 : 570. 正答率(テスト) = 0.7271
# Generation: 580. 正答率(トレーニング) = 0.91
#                 : 580. 正答率(テスト) = 0.7265
# Generation: 590. 正答率(トレーニング) = 0.92
#                 : 590. 正答率(テスト) = 0.7304
# Generation: 600. 正答率(トレーニング) = 0.9066666666666666
#                 : 600. 正答率(テスト) = 0.7218
# Generation: 610. 正答率(トレーニング) = 0.9066666666666666
#                 : 610. 正答率(テスト) = 0.7246
# Generation: 620. 正答率(トレーニング) = 0.9033333333333333
#                 : 620. 正答率(テスト) = 0.7279
# Generation: 630. 正答率(トレーニング) = 0.92
#                 : 630. 正答率(テスト) = 0.7213
# Generation: 640. 正答率(トレーニング) = 0.9033333333333333
#                 : 640. 正答率(テスト) = 0.7228
# Generation: 650. 正答率(トレーニング) = 0.9066666666666666
#                 : 650. 正答率(テスト) = 0.7226
# Generation: 660. 正答率(トレーニング) = 0.9
#                 : 660. 正答率(テスト) = 0.7198
# Generation: 670. 正答率(トレーニング) = 0.8966666666666666
#                 : 670. 正答率(テスト) = 0.7225
# Generation: 680. 正答率(トレーニング) = 0.9066666666666666
#                 : 680. 正答率(テスト) = 0.7244
# Generation: 690. 正答率(トレーニング) = 0.9033333333333333
#                 : 690. 正答率(テスト) = 0.7189
# Generation: 700. 正答率(トレーニング) = 0.8966666666666666
#                 : 700. 正答率(テスト) = 0.7158
# Generation: 710. 正答率(トレーニング) = 0.9133333333333333
#                 : 710. 正答率(テスト) = 0.7197
# Generation: 720. 正答率(トレーニング) = 0.8966666666666666
#                 : 720. 正答率(テスト) = 0.7215
# Generation: 730. 正答率(トレーニング) = 0.9166666666666666
#                 : 730. 正答率(テスト) = 0.7218
# Generation: 740. 正答率(トレーニング) = 0.91
#                 : 740. 正答率(テスト) = 0.7205
# Generation: 750. 正答率(トレーニング) = 0.9133333333333333
#                 : 750. 正答率(テスト) = 0.7198
# Generation: 760. 正答率(トレーニング) = 0.89
#                 : 760. 正答率(テスト) = 0.7112
# Generation: 770. 正答率(トレーニング) = 0.8933333333333333
#                 : 770. 正答率(テスト) = 0.713
# Generation: 780. 正答率(トレーニング) = 0.88
#                 : 780. 正答率(テスト) = 0.7081
# Generation: 790. 正答率(トレーニング) = 0.9033333333333333
#                 : 790. 正答率(テスト) = 0.7135
# Generation: 800. 正答率(トレーニング) = 0.8966666666666666
#                 : 800. 正答率(テスト) = 0.7127
# Generation: 810. 正答率(トレーニング) = 0.9
#                 : 810. 正答率(テスト) = 0.7134
# Generation: 820. 正答率(トレーニング) = 0.8933333333333333
#                 : 820. 正答率(テスト) = 0.7109
# Generation: 830. 正答率(トレーニング) = 0.9
#                 : 830. 正答率(テスト) = 0.7072
# Generation: 840. 正答率(トレーニング) = 0.8966666666666666
#                 : 840. 正答率(テスト) = 0.7097
# Generation: 850. 正答率(トレーニング) = 0.89
#                 : 850. 正答率(テスト) = 0.7065
# Generation: 860. 正答率(トレーニング) = 0.9166666666666666
#                 : 860. 正答率(テスト) = 0.7162
# Generation: 870. 正答率(トレーニング) = 0.8966666666666666
#                 : 870. 正答率(テスト) = 0.7141
# Generation: 880. 正答率(トレーニング) = 0.89
#                 : 880. 正答率(テスト) = 0.7062
# Generation: 890. 正答率(トレーニング) = 0.9033333333333333
#                 : 890. 正答率(テスト) = 0.7088
# Generation: 900. 正答率(トレーニング) = 0.9033333333333333
#                 : 900. 正答率(テスト) = 0.7108
# Generation: 910. 正答率(トレーニング) = 0.8833333333333333
#                 : 910. 正答率(テスト) = 0.7043
# Generation: 920. 正答率(トレーニング) = 0.9
#                 : 920. 正答率(テスト) = 0.7122
# Generation: 930. 正答率(トレーニング) = 0.8833333333333333
#                 : 930. 正答率(テスト) = 0.6971
# Generation: 940. 正答率(トレーニング) = 0.89
#                 : 940. 正答率(テスト) = 0.7046
# Generation: 950. 正答率(トレーニング) = 0.8866666666666667
#                 : 950. 正答率(テスト) = 0.7004
# Generation: 960. 正答率(トレーニング) = 0.8933333333333333
#                 : 960. 正答率(テスト) = 0.7012
# Generation: 970. 正答率(トレーニング) = 0.8933333333333333
#                 : 970. 正答率(テスト) = 0.706
# Generation: 980. 正答率(トレーニング) = 0.8766666666666667
#                 : 980. 正答率(テスト) = 0.6982
# Generation: 990. 正答率(トレーニング) = 0.8933333333333333
#                 : 990. 正答率(テスト) = 0.7055
# Generation: 1000. 正答率(トレーニング) = 0.8933333333333333
#                 : 1000. 正答率(テスト) = 0.7067

# %% [markdown]
# ### L1

# %%
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True)

print("データ読み込み完了")

# 過学習を再現するために、学習データを削減
x_train = x_train[:300]
d_train = d_train[:300]

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10)


iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100
learning_rate=0.1

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10
hidden_layer_num = network.hidden_layer_num

# 正則化強度設定 ======================================
weight_decay_lambda = 0.005
# =================================================

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    grad = network.gradient(x_batch, d_batch)
    weight_decay = 0
    
    for idx in range(1, hidden_layer_num+1):
        grad['W' + str(idx)] = network.layers['Affine' + str(idx)].dW + weight_decay_lambda * np.sign(network.params['W' + str(idx)])
        grad['b' + str(idx)] = network.layers['Affine' + str(idx)].db
        network.params['W' + str(idx)] -= learning_rate * grad['W' + str(idx)]
        network.params['b' + str(idx)] -= learning_rate * grad['b' + str(idx)]        
        weight_decay += weight_decay_lambda * np.sum(np.abs(network.params['W' + str(idx)]))

    loss = network.loss(x_batch, d_batch) + weight_decay
    train_loss_list.append(loss)        
        
    if (i+1) % plot_interval == 0:
        accr_train = network.accuracy(x_train, d_train)
        accr_test = network.accuracy(x_test, d_test)
        accuracies_train.append(accr_train)
        accuracies_test.append(accr_test)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))               
                
lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.6
#                 : 10. 正答率(テスト) = 0.4592
# Generation: 20. 正答率(トレーニング) = 0.5933333333333334
#                 : 20. 正答率(テスト) = 0.4824
# Generation: 30. 正答率(トレーニング) = 0.7533333333333333
#                 : 30. 正答率(テスト) = 0.6311
# Generation: 40. 正答率(トレーニング) = 0.8233333333333334
#                 : 40. 正答率(テスト) = 0.658
# Generation: 50. 正答率(トレーニング) = 0.83
#                 : 50. 正答率(テスト) = 0.6399
# Generation: 60. 正答率(トレーニング) = 0.8
#                 : 60. 正答率(テスト) = 0.6208
# Generation: 70. 正答率(トレーニング) = 0.92
#                 : 70. 正答率(テスト) = 0.7577
# Generation: 80. 正答率(トレーニング) = 0.91
#                 : 80. 正答率(テスト) = 0.7098
# Generation: 90. 正答率(トレーニング) = 0.9
#                 : 90. 正答率(テスト) = 0.707
# Generation: 100. 正答率(トレーニング) = 0.8833333333333333
#                 : 100. 正答率(テスト) = 0.7198
# Generation: 110. 正答率(トレーニング) = 0.95
#                 : 110. 正答率(テスト) = 0.7825
# Generation: 120. 正答率(トレーニング) = 0.83
#                 : 120. 正答率(テスト) = 0.6771
# Generation: 130. 正答率(トレーニング) = 0.8633333333333333
#                 : 130. 正答率(テスト) = 0.6913
# Generation: 140. 正答率(トレーニング) = 0.9266666666666666
#                 : 140. 正答率(テスト) = 0.7502
# Generation: 150. 正答率(トレーニング) = 0.9033333333333333
#                 : 150. 正答率(テスト) = 0.7319
# Generation: 160. 正答率(トレーニング) = 0.9333333333333333
#                 : 160. 正答率(テスト) = 0.7556
# Generation: 170. 正答率(トレーニング) = 0.8166666666666667
#                 : 170. 正答率(テスト) = 0.6527
# Generation: 180. 正答率(トレーニング) = 0.6466666666666666
#                 : 180. 正答率(テスト) = 0.5077
# Generation: 190. 正答率(トレーニング) = 0.7066666666666667
#                 : 190. 正答率(テスト) = 0.5914
# Generation: 200. 正答率(トレーニング) = 0.94
#                 : 200. 正答率(テスト) = 0.7674
# Generation: 210. 正答率(トレーニング) = 0.9333333333333333
#                 : 210. 正答率(テスト) = 0.7629
# Generation: 220. 正答率(トレーニング) = 0.68
#                 : 220. 正答率(テスト) = 0.4938
# Generation: 230. 正答率(トレーニング) = 0.89
#                 : 230. 正答率(テスト) = 0.6984
# Generation: 240. 正答率(トレーニング) = 0.9
#                 : 240. 正答率(テスト) = 0.7072
# Generation: 250. 正答率(トレーニング) = 0.8933333333333333
#                 : 250. 正答率(テスト) = 0.6885
# Generation: 260. 正答率(トレーニング) = 0.9233333333333333
#                 : 260. 正答率(テスト) = 0.7465
# Generation: 270. 正答率(トレーニング) = 0.8466666666666667
#                 : 270. 正答率(テスト) = 0.672
# Generation: 280. 正答率(トレーニング) = 0.8033333333333333
#                 : 280. 正答率(テスト) = 0.6399
# Generation: 290. 正答率(トレーニング) = 0.9033333333333333
#                 : 290. 正答率(テスト) = 0.6948
# Generation: 300. 正答率(トレーニング) = 0.9033333333333333
#                 : 300. 正答率(テスト) = 0.7253
# Generation: 310. 正答率(トレーニング) = 0.74
#                 : 310. 正答率(テスト) = 0.5855
# Generation: 320. 正答率(トレーニング) = 0.92
#                 : 320. 正答率(テスト) = 0.7413
# Generation: 330. 正答率(トレーニング) = 0.92
#                 : 330. 正答率(テスト) = 0.7274
# Generation: 340. 正答率(トレーニング) = 0.9133333333333333
#                 : 340. 正答率(テスト) = 0.7299
# Generation: 350. 正答率(トレーニング) = 0.9333333333333333
#                 : 350. 正答率(テスト) = 0.7491
# Generation: 360. 正答率(トレーニング) = 0.9533333333333334
#                 : 360. 正答率(テスト) = 0.7383
# Generation: 370. 正答率(トレーニング) = 0.8666666666666667
#                 : 370. 正答率(テスト) = 0.6644
# Generation: 380. 正答率(トレーニング) = 0.9
#                 : 380. 正答率(テスト) = 0.6763
# Generation: 390. 正答率(トレーニング) = 0.78
#                 : 390. 正答率(テスト) = 0.6282
# Generation: 400. 正答率(トレーニング) = 0.7633333333333333
#                 : 400. 正答率(テスト) = 0.5819
# Generation: 410. 正答率(トレーニング) = 0.65
#                 : 410. 正答率(テスト) = 0.491
# Generation: 420. 正答率(トレーニング) = 0.74
#                 : 420. 正答率(テスト) = 0.5754
# Generation: 430. 正答率(トレーニング) = 0.8866666666666667
#                 : 430. 正答率(テスト) = 0.6823
# Generation: 440. 正答率(トレーニング) = 0.8733333333333333
#                 : 440. 正答率(テスト) = 0.6916
# Generation: 450. 正答率(トレーニング) = 0.89
#                 : 450. 正答率(テスト) = 0.6594
# Generation: 460. 正答率(トレーニング) = 0.93
#                 : 460. 正答率(テスト) = 0.7345
# Generation: 470. 正答率(トレーニング) = 0.6233333333333333
#                 : 470. 正答率(テスト) = 0.4676
# Generation: 480. 正答率(トレーニング) = 0.9066666666666666
#                 : 480. 正答率(テスト) = 0.69
# Generation: 490. 正答率(トレーニング) = 0.7766666666666666
#                 : 490. 正答率(テスト) = 0.5851
# Generation: 500. 正答率(トレーニング) = 0.9133333333333333
#                 : 500. 正答率(テスト) = 0.7189
# Generation: 510. 正答率(トレーニング) = 0.95
#                 : 510. 正答率(テスト) = 0.6995
# Generation: 520. 正答率(トレーニング) = 0.9433333333333334
#                 : 520. 正答率(テスト) = 0.7117
# Generation: 530. 正答率(トレーニング) = 0.9233333333333333
#                 : 530. 正答率(テスト) = 0.7075
# Generation: 540. 正答率(トレーニング) = 0.9533333333333334
#                 : 540. 正答率(テスト) = 0.7248
# Generation: 550. 正答率(トレーニング) = 0.6766666666666666
#                 : 550. 正答率(テスト) = 0.4999
# Generation: 560. 正答率(トレーニング) = 0.9666666666666667
#                 : 560. 正答率(テスト) = 0.7405
# Generation: 570. 正答率(トレーニング) = 0.9466666666666667
#                 : 570. 正答率(テスト) = 0.7013
# Generation: 580. 正答率(トレーニング) = 0.97
#                 : 580. 正答率(テスト) = 0.7344
# Generation: 590. 正答率(トレーニング) = 0.9566666666666667
#                 : 590. 正答率(テスト) = 0.7135
# Generation: 600. 正答率(トレーニング) = 0.94
#                 : 600. 正答率(テスト) = 0.7223
# Generation: 610. 正答率(トレーニング) = 0.98
#                 : 610. 正答率(テスト) = 0.7434
# Generation: 620. 正答率(トレーニング) = 0.9133333333333333
#                 : 620. 正答率(テスト) = 0.6862
# Generation: 630. 正答率(トレーニング) = 0.85
#                 : 630. 正答率(テスト) = 0.6512
# Generation: 640. 正答率(トレーニング) = 0.9066666666666666
#                 : 640. 正答率(テスト) = 0.6611
# Generation: 650. 正答率(トレーニング) = 0.95
#                 : 650. 正答率(テスト) = 0.7151
# Generation: 660. 正答率(トレーニング) = 0.9766666666666667
#                 : 660. 正答率(テスト) = 0.7401
# Generation: 670. 正答率(トレーニング) = 0.87
#                 : 670. 正答率(テスト) = 0.6257
# Generation: 680. 正答率(トレーニング) = 0.97
#                 : 680. 正答率(テスト) = 0.7182
# Generation: 690. 正答率(トレーニング) = 0.93
#                 : 690. 正答率(テスト) = 0.7091
# Generation: 700. 正答率(トレーニング) = 0.8466666666666667
#                 : 700. 正答率(テスト) = 0.6531
# Generation: 710. 正答率(トレーニング) = 0.97
#                 : 710. 正答率(テスト) = 0.7433
# Generation: 720. 正答率(トレーニング) = 0.9033333333333333
#                 : 720. 正答率(テスト) = 0.6777
# Generation: 730. 正答率(トレーニング) = 0.87
#                 : 730. 正答率(テスト) = 0.6517
# Generation: 740. 正答率(トレーニング) = 0.98
#                 : 740. 正答率(テスト) = 0.7165
# Generation: 750. 正答率(トレーニング) = 0.99
#                 : 750. 正答率(テスト) = 0.7339
# Generation: 760. 正答率(トレーニング) = 0.98
#                 : 760. 正答率(テスト) = 0.7334
# Generation: 770. 正答率(トレーニング) = 0.62
#                 : 770. 正答率(テスト) = 0.5311
# Generation: 780. 正答率(トレーニング) = 0.8866666666666667
#                 : 780. 正答率(テスト) = 0.6627
# Generation: 790. 正答率(トレーニング) = 0.99
#                 : 790. 正答率(テスト) = 0.7469
# Generation: 800. 正答率(トレーニング) = 0.99
#                 : 800. 正答率(テスト) = 0.7402
# Generation: 810. 正答率(トレーニング) = 0.4633333333333333
#                 : 810. 正答率(テスト) = 0.4056
# Generation: 820. 正答率(トレーニング) = 0.9833333333333333
#                 : 820. 正答率(テスト) = 0.7311
# Generation: 830. 正答率(トレーニング) = 0.99
#                 : 830. 正答率(テスト) = 0.74
# Generation: 840. 正答率(トレーニング) = 0.9733333333333334
#                 : 840. 正答率(テスト) = 0.7263
# Generation: 850. 正答率(トレーニング) = 0.9933333333333333
#                 : 850. 正答率(テスト) = 0.736
# Generation: 860. 正答率(トレーニング) = 0.9866666666666667
#                 : 860. 正答率(テスト) = 0.7172
# Generation: 870. 正答率(トレーニング) = 0.97
#                 : 870. 正答率(テスト) = 0.7297
# Generation: 880. 正答率(トレーニング) = 0.9866666666666667
#                 : 880. 正答率(テスト) = 0.7364
# Generation: 890. 正答率(トレーニング) = 0.98
#                 : 890. 正答率(テスト) = 0.7127
# Generation: 900. 正答率(トレーニング) = 0.7166666666666667
#                 : 900. 正答率(テスト) = 0.5256
# Generation: 910. 正答率(トレーニング) = 0.9766666666666667
#                 : 910. 正答率(テスト) = 0.7391
# Generation: 920. 正答率(トレーニング) = 0.9866666666666667
#                 : 920. 正答率(テスト) = 0.7452
# Generation: 930. 正答率(トレーニング) = 0.9933333333333333
#                 : 930. 正答率(テスト) = 0.7452
# Generation: 940. 正答率(トレーニング) = 0.96
#                 : 940. 正答率(テスト) = 0.7208
# Generation: 950. 正答率(トレーニング) = 0.9933333333333333
#                 : 950. 正答率(テスト) = 0.7404
# Generation: 960. 正答率(トレーニング) = 0.96
#                 : 960. 正答率(テスト) = 0.6964
# Generation: 970. 正答率(トレーニング) = 0.87
#                 : 970. 正答率(テスト) = 0.6585
# Generation: 980. 正答率(トレーニング) = 0.9966666666666667
#                 : 980. 正答率(テスト) = 0.7451
# Generation: 990. 正答率(トレーニング) = 1.0
#                 : 990. 正答率(テスト) = 0.7439
# Generation: 1000. 正答率(トレーニング) = 0.98
#                 : 1000. 正答率(テスト) = 0.7347

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------
# ## [try] weigth_decay_lambdaの値を変更して正則化の強さを確認しよう
# ----------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Dropout

# %%
class Dropout:
    def __init__(self, dropout_ratio=0.5):
        self.dropout_ratio = dropout_ratio
        self.mask = None

    def forward(self, x, train_flg=True):
        if train_flg:
            self.mask = np.random.rand(*x.shape) > self.dropout_ratio
            return x * self.mask
        else:
            return x * (1.0 - self.dropout_ratio)

    def backward(self, dout):
        return dout * self.mask

# %%
from common import optimizer
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True)

print("データ読み込み完了")

# 過学習を再現するために、学習データを削減
x_train = x_train[:300]
d_train = d_train[:300]

# ドロップアウト設定 ======================================
use_dropout = True
dropout_ratio = 0.15
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        weight_decay_lambda=weight_decay_lambda, use_dropout = use_dropout, dropout_ratio = dropout_ratio)
optimizer = optimizer.SGD(learning_rate=0.01)
# optimizer = optimizer.Momentum(learning_rate=0.01, momentum=0.9)
# optimizer = optimizer.AdaGrad(learning_rate=0.01)
# optimizer = optimizer.Adam()

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10


for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    grad = network.gradient(x_batch, d_batch)
    optimizer.update(network.params, grad)

    loss = network.loss(x_batch, d_batch)
    train_loss_list.append(loss)    
    
    if (i+1) % plot_interval == 0:
        accr_train = network.accuracy(x_train, d_train)
        accr_test = network.accuracy(x_test, d_test)
        accuracies_train.append(accr_train)
        accuracies_test.append(accr_test)

        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))        
        
lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.1
#                 : 10. 正答率(テスト) = 0.0972
# Generation: 20. 正答率(トレーニング) = 0.11
#                 : 20. 正答率(テスト) = 0.1067
# Generation: 30. 正答率(トレーニング) = 0.15
#                 : 30. 正答率(テスト) = 0.1375
# Generation: 40. 正答率(トレーニング) = 0.20333333333333334
#                 : 40. 正答率(テスト) = 0.1822
# Generation: 50. 正答率(トレーニング) = 0.22333333333333333
#                 : 50. 正答率(テスト) = 0.1975
# Generation: 60. 正答率(トレーニング) = 0.24333333333333335
#                 : 60. 正答率(テスト) = 0.2146
# Generation: 70. 正答率(トレーニング) = 0.25666666666666665
#                 : 70. 正答率(テスト) = 0.229
# Generation: 80. 正答率(トレーニング) = 0.29
#                 : 80. 正答率(テスト) = 0.2449
# Generation: 90. 正答率(トレーニング) = 0.3233333333333333
#                 : 90. 正答率(テスト) = 0.2676
# Generation: 100. 正答率(トレーニング) = 0.32666666666666666
#                 : 100. 正答率(テスト) = 0.2816
# Generation: 110. 正答率(トレーニング) = 0.33666666666666667
#                 : 110. 正答率(テスト) = 0.2919
# Generation: 120. 正答率(トレーニング) = 0.3333333333333333
#                 : 120. 正答率(テスト) = 0.295
# Generation: 130. 正答率(トレーニング) = 0.3333333333333333
#                 : 130. 正答率(テスト) = 0.2982
# Generation: 140. 正答率(トレーニング) = 0.3433333333333333
#                 : 140. 正答率(テスト) = 0.2984
# Generation: 150. 正答率(トレーニング) = 0.3333333333333333
#                 : 150. 正答率(テスト) = 0.2966
# Generation: 160. 正答率(トレーニング) = 0.3466666666666667
#                 : 160. 正答率(テスト) = 0.3001
# Generation: 170. 正答率(トレーニング) = 0.3466666666666667
#                 : 170. 正答率(テスト) = 0.2937
# Generation: 180. 正答率(トレーニング) = 0.35333333333333333
#                 : 180. 正答率(テスト) = 0.3001
# Generation: 190. 正答率(トレーニング) = 0.3566666666666667
#                 : 190. 正答率(テスト) = 0.2961
# Generation: 200. 正答率(トレーニング) = 0.35333333333333333
#                 : 200. 正答率(テスト) = 0.2969
# Generation: 210. 正答率(トレーニング) = 0.3466666666666667
#                 : 210. 正答率(テスト) = 0.2944
# Generation: 220. 正答率(トレーニング) = 0.35333333333333333
#                 : 220. 正答率(テスト) = 0.2971
# Generation: 230. 正答率(トレーニング) = 0.37666666666666665
#                 : 230. 正答率(テスト) = 0.3044
# Generation: 240. 正答率(トレーニング) = 0.38666666666666666
#                 : 240. 正答率(テスト) = 0.3108
# Generation: 250. 正答率(トレーニング) = 0.4
#                 : 250. 正答率(テスト) = 0.3148
# Generation: 260. 正答率(トレーニング) = 0.41333333333333333
#                 : 260. 正答率(テスト) = 0.3192
# Generation: 270. 正答率(トレーニング) = 0.43
#                 : 270. 正答率(テスト) = 0.3347
# Generation: 280. 正答率(トレーニング) = 0.43666666666666665
#                 : 280. 正答率(テスト) = 0.3383
# Generation: 290. 正答率(トレーニング) = 0.45
#                 : 290. 正答率(テスト) = 0.3552
# Generation: 300. 正答率(トレーニング) = 0.45666666666666667
#                 : 300. 正答率(テスト) = 0.3717
# Generation: 310. 正答率(トレーニング) = 0.47333333333333333
#                 : 310. 正答率(テスト) = 0.3727
# Generation: 320. 正答率(トレーニング) = 0.4766666666666667
#                 : 320. 正答率(テスト) = 0.3783
# Generation: 330. 正答率(トレーニング) = 0.49666666666666665
#                 : 330. 正答率(テスト) = 0.3946
# Generation: 340. 正答率(トレーニング) = 0.51
#                 : 340. 正答率(テスト) = 0.4033
# Generation: 350. 正答率(トレーニング) = 0.5266666666666666
#                 : 350. 正答率(テスト) = 0.4297
# Generation: 360. 正答率(トレーニング) = 0.5433333333333333
#                 : 360. 正答率(テスト) = 0.4471
# Generation: 370. 正答率(トレーニング) = 0.5666666666666667
#                 : 370. 正答率(テスト) = 0.4617
# Generation: 380. 正答率(トレーニング) = 0.5833333333333334
#                 : 380. 正答率(テスト) = 0.4635
# Generation: 390. 正答率(トレーニング) = 0.59
#                 : 390. 正答率(テスト) = 0.476
# Generation: 400. 正答率(トレーニング) = 0.6
#                 : 400. 正答率(テスト) = 0.4852
# Generation: 410. 正答率(トレーニング) = 0.6
#                 : 410. 正答率(テスト) = 0.4934
# Generation: 420. 正答率(トレーニング) = 0.6166666666666667
#                 : 420. 正答率(テスト) = 0.5071
# Generation: 430. 正答率(トレーニング) = 0.6133333333333333
#                 : 430. 正答率(テスト) = 0.5098
# Generation: 440. 正答率(トレーニング) = 0.62
#                 : 440. 正答率(テスト) = 0.5213
# Generation: 450. 正答率(トレーニング) = 0.62
#                 : 450. 正答率(テスト) = 0.5282
# Generation: 460. 正答率(トレーニング) = 0.62
#                 : 460. 正答率(テスト) = 0.533
# Generation: 470. 正答率(トレーニング) = 0.62
#                 : 470. 正答率(テスト) = 0.5384
# Generation: 480. 正答率(トレーニング) = 0.63
#                 : 480. 正答率(テスト) = 0.5407
# Generation: 490. 正答率(トレーニング) = 0.63
#                 : 490. 正答率(テスト) = 0.5483
# Generation: 500. 正答率(トレーニング) = 0.6333333333333333
#                 : 500. 正答率(テスト) = 0.5557
# Generation: 510. 正答率(トレーニング) = 0.6466666666666666
#                 : 510. 正答率(テスト) = 0.561
# Generation: 520. 正答率(トレーニング) = 0.6433333333333333
#                 : 520. 正答率(テスト) = 0.5612
# Generation: 530. 正答率(トレーニング) = 0.6466666666666666
#                 : 530. 正答率(テスト) = 0.5673
# Generation: 540. 正答率(トレーニング) = 0.6533333333333333
#                 : 540. 正答率(テスト) = 0.5752
# Generation: 550. 正答率(トレーニング) = 0.6733333333333333
#                 : 550. 正答率(テスト) = 0.5847
# Generation: 560. 正答率(トレーニング) = 0.6833333333333333
#                 : 560. 正答率(テスト) = 0.589
# Generation: 570. 正答率(トレーニング) = 0.6933333333333334
#                 : 570. 正答率(テスト) = 0.5964
# Generation: 580. 正答率(トレーニング) = 0.6866666666666666
#                 : 580. 正答率(テスト) = 0.5974
# Generation: 590. 正答率(トレーニング) = 0.6833333333333333
#                 : 590. 正答率(テスト) = 0.5984
# Generation: 600. 正答率(トレーニング) = 0.6966666666666667
#                 : 600. 正答率(テスト) = 0.6055
# Generation: 610. 正答率(トレーニング) = 0.71
#                 : 610. 正答率(テスト) = 0.6147
# Generation: 620. 正答率(トレーニング) = 0.7133333333333334
#                 : 620. 正答率(テスト) = 0.6168
# Generation: 630. 正答率(トレーニング) = 0.7166666666666667
#                 : 630. 正答率(テスト) = 0.6208
# Generation: 640. 正答率(トレーニング) = 0.72
#                 : 640. 正答率(テスト) = 0.6279
# Generation: 650. 正答率(トレーニング) = 0.7266666666666667
#                 : 650. 正答率(テスト) = 0.6333
# Generation: 660. 正答率(トレーニング) = 0.7333333333333333
#                 : 660. 正答率(テスト) = 0.6363
# Generation: 670. 正答率(トレーニング) = 0.7433333333333333
#                 : 670. 正答率(テスト) = 0.6429
# Generation: 680. 正答率(トレーニング) = 0.7466666666666667
#                 : 680. 正答率(テスト) = 0.6384
# Generation: 690. 正答率(トレーニング) = 0.7433333333333333
#                 : 690. 正答率(テスト) = 0.6448
# Generation: 700. 正答率(トレーニング) = 0.76
#                 : 700. 正答率(テスト) = 0.6492
# Generation: 710. 正答率(トレーニング) = 0.76
#                 : 710. 正答率(テスト) = 0.6458
# Generation: 720. 正答率(トレーニング) = 0.7633333333333333
#                 : 720. 正答率(テスト) = 0.6539
# Generation: 730. 正答率(トレーニング) = 0.7833333333333333
#                 : 730. 正答率(テスト) = 0.6611
# Generation: 740. 正答率(トレーニング) = 0.79
#                 : 740. 正答率(テスト) = 0.6683
# Generation: 750. 正答率(トレーニング) = 0.8033333333333333
#                 : 750. 正答率(テスト) = 0.676
# Generation: 760. 正答率(トレーニング) = 0.8066666666666666
#                 : 760. 正答率(テスト) = 0.6812
# Generation: 770. 正答率(トレーニング) = 0.8133333333333334
#                 : 770. 正答率(テスト) = 0.679
# Generation: 780. 正答率(トレーニング) = 0.8233333333333334
#                 : 780. 正答率(テスト) = 0.6851
# Generation: 790. 正答率(トレーニング) = 0.8266666666666667
#                 : 790. 正答率(テスト) = 0.6892
# Generation: 800. 正答率(トレーニング) = 0.8433333333333334
#                 : 800. 正答率(テスト) = 0.6961
# Generation: 810. 正答率(トレーニング) = 0.8466666666666667
#                 : 810. 正答率(テスト) = 0.6984
# Generation: 820. 正答率(トレーニング) = 0.8333333333333334
#                 : 820. 正答率(テスト) = 0.6924
# Generation: 830. 正答率(トレーニング) = 0.85
#                 : 830. 正答率(テスト) = 0.6985
# Generation: 840. 正答率(トレーニング) = 0.8333333333333334
#                 : 840. 正答率(テスト) = 0.6965
# Generation: 850. 正答率(トレーニング) = 0.8466666666666667
#                 : 850. 正答率(テスト) = 0.7044
# Generation: 860. 正答率(トレーニング) = 0.8566666666666667
#                 : 860. 正答率(テスト) = 0.7061
# Generation: 870. 正答率(トレーニング) = 0.8733333333333333
#                 : 870. 正答率(テスト) = 0.7111
# Generation: 880. 正答率(トレーニング) = 0.87
#                 : 880. 正答率(テスト) = 0.7121
# Generation: 890. 正答率(トレーニング) = 0.8733333333333333
#                 : 890. 正答率(テスト) = 0.7142
# Generation: 900. 正答率(トレーニング) = 0.8633333333333333
#                 : 900. 正答率(テスト) = 0.7116
# Generation: 910. 正答率(トレーニング) = 0.88
#                 : 910. 正答率(テスト) = 0.719
# Generation: 920. 正答率(トレーニング) = 0.8866666666666667
#                 : 920. 正答率(テスト) = 0.7238
# Generation: 930. 正答率(トレーニング) = 0.8766666666666667
#                 : 930. 正答率(テスト) = 0.718
# Generation: 940. 正答率(トレーニング) = 0.8766666666666667
#                 : 940. 正答率(テスト) = 0.7222
# Generation: 950. 正答率(トレーニング) = 0.8966666666666666
#                 : 950. 正答率(テスト) = 0.7246
# Generation: 960. 正答率(トレーニング) = 0.89
#                 : 960. 正答率(テスト) = 0.7235
# Generation: 970. 正答率(トレーニング) = 0.8833333333333333
#                 : 970. 正答率(テスト) = 0.728
# Generation: 980. 正答率(トレーニング) = 0.8966666666666666
#                 : 980. 正答率(テスト) = 0.7294
# Generation: 990. 正答率(トレーニング) = 0.8966666666666666
#                 : 990. 正答率(テスト) = 0.7314
# Generation: 1000. 正答率(トレーニング) = 0.9066666666666666
#                 : 1000. 正答率(テスト) = 0.7313

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ## [try] dropout_ratioの値を変更してみよう

# %% [markdown]
# ## [try] optimizerとdropout_ratioの値を変更してみよう
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Dropout + L1

# %%
from common import optimizer
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True)

print("データ読み込み完了")

# 過学習を再現するために、学習データを削減
x_train = x_train[:300]
d_train = d_train[:300]

# ドロップアウト設定 ======================================
use_dropout = True
dropout_ratio = 0.08
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        use_dropout = use_dropout, dropout_ratio = dropout_ratio)

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100
learning_rate=0.01

train_loss_list = []
accuracies_train = []
accuracies_test = []
hidden_layer_num = network.hidden_layer_num

plot_interval=10

# 正則化強度設定 ======================================
weight_decay_lambda=0.004
# =================================================

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    grad = network.gradient(x_batch, d_batch)
    weight_decay = 0
    
    for idx in range(1, hidden_layer_num+1):
        grad['W' + str(idx)] = network.layers['Affine' + str(idx)].dW + weight_decay_lambda * np.sign(network.params['W' + str(idx)])
        grad['b' + str(idx)] = network.layers['Affine' + str(idx)].db
        network.params['W' + str(idx)] -= learning_rate * grad['W' + str(idx)]
        network.params['b' + str(idx)] -= learning_rate * grad['b' + str(idx)]        
        weight_decay += weight_decay_lambda * np.sum(np.abs(network.params['W' + str(idx)]))

    loss = network.loss(x_batch, d_batch) + weight_decay
    train_loss_list.append(loss)        
        
    if (i+1) % plot_interval == 0:
        accr_train = network.accuracy(x_train, d_train)
        accr_test = network.accuracy(x_test, d_test)
        accuracies_train.append(accr_train)
        accuracies_test.append(accr_test)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))               
        
lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.11666666666666667
#                 : 10. 正答率(テスト) = 0.1412
# Generation: 20. 正答率(トレーニング) = 0.17333333333333334
#                 : 20. 正答率(テスト) = 0.1755
# Generation: 30. 正答率(トレーニング) = 0.23666666666666666
#                 : 30. 正答率(テスト) = 0.1987
# Generation: 40. 正答率(トレーニング) = 0.25
#                 : 40. 正答率(テスト) = 0.224
# Generation: 50. 正答率(トレーニング) = 0.2633333333333333
#                 : 50. 正答率(テスト) = 0.2413
# Generation: 60. 正答率(トレーニング) = 0.29
#                 : 60. 正答率(テスト) = 0.2582
# Generation: 70. 正答率(トレーニング) = 0.3333333333333333
#                 : 70. 正答率(テスト) = 0.2838
# Generation: 80. 正答率(トレーニング) = 0.36
#                 : 80. 正答率(テスト) = 0.3013
# Generation: 90. 正答率(トレーニング) = 0.38
#                 : 90. 正答率(テスト) = 0.3165
# Generation: 100. 正答率(トレーニング) = 0.43333333333333335
#                 : 100. 正答率(テスト) = 0.3339
# Generation: 110. 正答率(トレーニング) = 0.4666666666666667
#                 : 110. 正答率(テスト) = 0.3521
# Generation: 120. 正答率(トレーニング) = 0.5
#                 : 120. 正答率(テスト) = 0.3645
# Generation: 130. 正答率(トレーニング) = 0.49
#                 : 130. 正答率(テスト) = 0.3646
# Generation: 140. 正答率(トレーニング) = 0.4866666666666667
#                 : 140. 正答率(テスト) = 0.3686
# Generation: 150. 正答率(トレーニング) = 0.5233333333333333
#                 : 150. 正答率(テスト) = 0.3914
# Generation: 160. 正答率(トレーニング) = 0.5366666666666666
#                 : 160. 正答率(テスト) = 0.4067
# Generation: 170. 正答率(トレーニング) = 0.56
#                 : 170. 正答率(テスト) = 0.4172
# Generation: 180. 正答率(トレーニング) = 0.57
#                 : 180. 正答率(テスト) = 0.4162
# Generation: 190. 正答率(トレーニング) = 0.58
#                 : 190. 正答率(テスト) = 0.4333
# Generation: 200. 正答率(トレーニング) = 0.5933333333333334
#                 : 200. 正答率(テスト) = 0.444
# Generation: 210. 正答率(トレーニング) = 0.6033333333333334
#                 : 210. 正答率(テスト) = 0.4503
# Generation: 220. 正答率(トレーニング) = 0.6133333333333333
#                 : 220. 正答率(テスト) = 0.4682
# Generation: 230. 正答率(トレーニング) = 0.63
#                 : 230. 正答率(テスト) = 0.4775
# Generation: 240. 正答率(トレーニング) = 0.6566666666666666
#                 : 240. 正答率(テスト) = 0.4922
# Generation: 250. 正答率(トレーニング) = 0.6733333333333333
#                 : 250. 正答率(テスト) = 0.5085
# Generation: 260. 正答率(トレーニング) = 0.6833333333333333
#                 : 260. 正答率(テスト) = 0.5161
# Generation: 270. 正答率(トレーニング) = 0.6866666666666666
#                 : 270. 正答率(テスト) = 0.5185
# Generation: 280. 正答率(トレーニング) = 0.7033333333333334
#                 : 280. 正答率(テスト) = 0.5311
# Generation: 290. 正答率(トレーニング) = 0.71
#                 : 290. 正答率(テスト) = 0.5461
# Generation: 300. 正答率(トレーニング) = 0.73
#                 : 300. 正答率(テスト) = 0.5573
# Generation: 310. 正答率(トレーニング) = 0.7233333333333334
#                 : 310. 正答率(テスト) = 0.5618
# Generation: 320. 正答率(トレーニング) = 0.7333333333333333
#                 : 320. 正答率(テスト) = 0.5685
# Generation: 330. 正答率(トレーニング) = 0.7266666666666667
#                 : 330. 正答率(テスト) = 0.5716
# Generation: 340. 正答率(トレーニング) = 0.73
#                 : 340. 正答率(テスト) = 0.5719
# Generation: 350. 正答率(トレーニング) = 0.7433333333333333
#                 : 350. 正答率(テスト) = 0.5906
# Generation: 360. 正答率(トレーニング) = 0.75
#                 : 360. 正答率(テスト) = 0.5932
# Generation: 370. 正答率(トレーニング) = 0.7633333333333333
#                 : 370. 正答率(テスト) = 0.6017
# Generation: 380. 正答率(トレーニング) = 0.78
#                 : 380. 正答率(テスト) = 0.6065
# Generation: 390. 正答率(トレーニング) = 0.79
#                 : 390. 正答率(テスト) = 0.6151
# Generation: 400. 正答率(トレーニング) = 0.7933333333333333
#                 : 400. 正答率(テスト) = 0.6176
# Generation: 410. 正答率(トレーニング) = 0.7933333333333333
#                 : 410. 正答率(テスト) = 0.6194
# Generation: 420. 正答率(トレーニング) = 0.8033333333333333
#                 : 420. 正答率(テスト) = 0.6249
# Generation: 430. 正答率(トレーニング) = 0.81
#                 : 430. 正答率(テスト) = 0.631
# Generation: 440. 正答率(トレーニング) = 0.8166666666666667
#                 : 440. 正答率(テスト) = 0.633
# Generation: 450. 正答率(トレーニング) = 0.8266666666666667
#                 : 450. 正答率(テスト) = 0.6521
# Generation: 460. 正答率(トレーニング) = 0.84
#                 : 460. 正答率(テスト) = 0.6605
# Generation: 470. 正答率(トレーニング) = 0.8266666666666667
#                 : 470. 正答率(テスト) = 0.659
# Generation: 480. 正答率(トレーニング) = 0.84
#                 : 480. 正答率(テスト) = 0.6651
# Generation: 490. 正答率(トレーニング) = 0.8533333333333334
#                 : 490. 正答率(テスト) = 0.6732
# Generation: 500. 正答率(トレーニング) = 0.8466666666666667
#                 : 500. 正答率(テスト) = 0.6689
# Generation: 510. 正答率(トレーニング) = 0.8566666666666667
#                 : 510. 正答率(テスト) = 0.6725
# Generation: 520. 正答率(トレーニング) = 0.8566666666666667
#                 : 520. 正答率(テスト) = 0.6751
# Generation: 530. 正答率(トレーニング) = 0.8533333333333334
#                 : 530. 正答率(テスト) = 0.679
# Generation: 540. 正答率(トレーニング) = 0.8633333333333333
#                 : 540. 正答率(テスト) = 0.6861
# Generation: 550. 正答率(トレーニング) = 0.8766666666666667
#                 : 550. 正答率(テスト) = 0.6943
# Generation: 560. 正答率(トレーニング) = 0.8866666666666667
#                 : 560. 正答率(テスト) = 0.6947
# Generation: 570. 正答率(トレーニング) = 0.8866666666666667
#                 : 570. 正答率(テスト) = 0.7002
# Generation: 580. 正答率(トレーニング) = 0.8933333333333333
#                 : 580. 正答率(テスト) = 0.7078
# Generation: 590. 正答率(トレーニング) = 0.9066666666666666
#                 : 590. 正答率(テスト) = 0.723
# Generation: 600. 正答率(トレーニング) = 0.8866666666666667
#                 : 600. 正答率(テスト) = 0.7062
# Generation: 610. 正答率(トレーニング) = 0.89
#                 : 610. 正答率(テスト) = 0.7113
# Generation: 620. 正答率(トレーニング) = 0.8933333333333333
#                 : 620. 正答率(テスト) = 0.7123
# Generation: 630. 正答率(トレーニング) = 0.8933333333333333
#                 : 630. 正答率(テスト) = 0.7177
# Generation: 640. 正答率(トレーニング) = 0.8966666666666666
#                 : 640. 正答率(テスト) = 0.7167
# Generation: 650. 正答率(トレーニング) = 0.89
#                 : 650. 正答率(テスト) = 0.7126
# Generation: 660. 正答率(トレーニング) = 0.9133333333333333
#                 : 660. 正答率(テスト) = 0.7361
# Generation: 670. 正答率(トレーニング) = 0.91
#                 : 670. 正答率(テスト) = 0.7296
# Generation: 680. 正答率(トレーニング) = 0.8966666666666666
#                 : 680. 正答率(テスト) = 0.7269
# Generation: 690. 正答率(トレーニング) = 0.9066666666666666
#                 : 690. 正答率(テスト) = 0.7346
# Generation: 700. 正答率(トレーニング) = 0.91
#                 : 700. 正答率(テスト) = 0.7328
# Generation: 710. 正答率(トレーニング) = 0.9066666666666666
#                 : 710. 正答率(テスト) = 0.7301
# Generation: 720. 正答率(トレーニング) = 0.9166666666666666
#                 : 720. 正答率(テスト) = 0.7378
# Generation: 730. 正答率(トレーニング) = 0.92
#                 : 730. 正答率(テスト) = 0.7344
# Generation: 740. 正答率(トレーニング) = 0.91
#                 : 740. 正答率(テスト) = 0.7341
# Generation: 750. 正答率(トレーニング) = 0.9133333333333333
#                 : 750. 正答率(テスト) = 0.7386
# Generation: 760. 正答率(トレーニング) = 0.9266666666666666
#                 : 760. 正答率(テスト) = 0.7476
# Generation: 770. 正答率(トレーニング) = 0.92
#                 : 770. 正答率(テスト) = 0.737
# Generation: 780. 正答率(トレーニング) = 0.9233333333333333
#                 : 780. 正答率(テスト) = 0.7546
# Generation: 790. 正答率(トレーニング) = 0.9166666666666666
#                 : 790. 正答率(テスト) = 0.7456
# Generation: 800. 正答率(トレーニング) = 0.92
#                 : 800. 正答率(テスト) = 0.7434
# Generation: 810. 正答率(トレーニング) = 0.9266666666666666
#                 : 810. 正答率(テスト) = 0.7547
# Generation: 820. 正答率(トレーニング) = 0.93
#                 : 820. 正答率(テスト) = 0.7499
# Generation: 830. 正答率(トレーニング) = 0.9366666666666666
#                 : 830. 正答率(テスト) = 0.7522
# Generation: 840. 正答率(トレーニング) = 0.93
#                 : 840. 正答率(テスト) = 0.7498
# Generation: 850. 正答率(トレーニング) = 0.9333333333333333
#                 : 850. 正答率(テスト) = 0.747
# Generation: 860. 正答率(トレーニング) = 0.94
#                 : 860. 正答率(テスト) = 0.7537
# Generation: 870. 正答率(トレーニング) = 0.9233333333333333
#                 : 870. 正答率(テスト) = 0.7468
# Generation: 880. 正答率(トレーニング) = 0.9333333333333333
#                 : 880. 正答率(テスト) = 0.7472
# Generation: 890. 正答率(トレーニング) = 0.9466666666666667
#                 : 890. 正答率(テスト) = 0.7608
# Generation: 900. 正答率(トレーニング) = 0.94
#                 : 900. 正答率(テスト) = 0.7625
# Generation: 910. 正答率(トレーニング) = 0.9466666666666667
#                 : 910. 正答率(テスト) = 0.7556
# Generation: 920. 正答率(トレーニング) = 0.9533333333333334
#                 : 920. 正答率(テスト) = 0.7631
# Generation: 930. 正答率(トレーニング) = 0.9566666666666667
#                 : 930. 正答率(テスト) = 0.766
# Generation: 940. 正答率(トレーニング) = 0.9533333333333334
#                 : 940. 正答率(テスト) = 0.7646
# Generation: 950. 正答率(トレーニング) = 0.96
#                 : 950. 正答率(テスト) = 0.7616
# Generation: 960. 正答率(トレーニング) = 0.96
#                 : 960. 正答率(テスト) = 0.7642
# Generation: 970. 正答率(トレーニング) = 0.9533333333333334
#                 : 970. 正答率(テスト) = 0.7727
# Generation: 980. 正答率(トレーニング) = 0.96
#                 : 980. 正答率(テスト) = 0.7717
# Generation: 990. 正答率(トレーニング) = 0.96
#                 : 990. 正答率(テスト) = 0.7713
# Generation: 1000. 正答率(トレーニング) = 0.96
#                 : 1000. 正答率(テスト) = 0.772
